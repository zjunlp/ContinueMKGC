# %%
import torch

torch.load('mre_train_dict.pth')
# Out:
# {0: ['0_pred_yolo_crop_1.png',
#   '0_pred_yolo_crop_0.png',
#   '0_pred_yolo_crop_2.png'],
#  1: ['1_pred_yolo_crop_3.png',
#   '1_pred_yolo_crop_6.png',
#   '1_pred_yolo_crop_4.png',
#   '1_pred_yolo_crop_5.png'],
#  2: ['2_pred_yolo_crop_8.png',
#   '2_pred_yolo_crop_10.png',
#   '2_pred_yolo_crop_9.png',
#   '2_pred_yolo_crop_7.png'],
#  3: ['3_pred_yolo_crop_14.png',
#   '3_pred_yolo_crop_11.png',
#   '3_pred_yolo_crop_12.png',
#   '3_pred_yolo_crop_13.png'],
#  4: ['4_pred_yolo_crop_17.png',
#   '4_pred_yolo_crop_15.png',
#   '4_pred_yolo_crop_16.png'],
#  5: ['5_pred_yolo_crop_21.png',
#   '5_pred_yolo_crop_19.png',
#   '5_pred_yolo_crop_20.png',
#   '5_pred_yolo_crop_18.png'],
#  6: ['6_pred_yolo_crop_23.png', '6_pred_yolo_crop_22.png'],
#  7: ['7_pred_yolo_crop_25.png', '7_pred_yolo_crop_24.png'],
#  8: ['8_pred_yolo_crop_26.png', '8_pred_yolo_crop_27.png'],
#  9: ['9_pred_yolo_crop_30.png',
#   '9_pred_yolo_crop_31.png',
#   '9_pred_yolo_crop_28.png',
# ...

# %%
torch.load('../vg_data/mre_test.pth')
# Out:
# [(0, 'twitter_stream_2018_10_10_13_0_2_142.jpg', 'Crocodile'),
#  (0, 'twitter_stream_2018_10_10_13_0_2_142.jpg', 'South Wales'),
#  (0, 'twitter_stream_2018_10_10_13_0_2_142.jpg', 'location'),
#  (1, 'twitter_19_31_22_54.jpg', 'Rafael Nadal'),
#  (1, 'twitter_19_31_22_54.jpg', 'Mery Perello'),
#  (1, 'twitter_19_31_22_54.jpg', 'person'),
#  (1, 'twitter_19_31_22_54.jpg', 'person'),
#  (2, 'twitter_stream_2018_09_04_13_0_2_48.jpg', '.Jack_Conklin78'),
#  (2, 'twitter_stream_2018_09_04_13_0_2_48.jpg', 'Titans'),
#  (2, 'twitter_stream_2018_09_04_13_0_2_48.jpg', 'person'),
#  (2, 'twitter_stream_2018_09_04_13_0_2_48.jpg', 'organization'),
#  (3, 'twitter_stream_2018_05_07_17_0_2_172.jpg', 'Fanart'),
#  (3, 'twitter_stream_2018_05_07_17_0_2_172.jpg', 'arashi_takemoto'),
#  (3, 'twitter_stream_2018_05_07_17_0_2_172.jpg', 'person'),
#  (3, 'twitter_stream_2018_05_07_17_0_2_172.jpg', 'person'),
#  (4, 'twitter_19_31_14_34.jpg', 'Declaw Bills'),
# ...

# %%
a = ['Nephew', 'Jake', 'age', '4', 'and', 'niece', 'Rosie', 'age', '7', 'months', '.', 'He', "'s", 'small', 'for', 'his', 'age', '(', 'and', 'she', "'s", 'huge', 'for', 'hers']
" ".join(a)
# Out:
# "Nephew Jake age 4 and niece Rosie age 7 months . He 's small for his age ( and she 's huge for hers"
